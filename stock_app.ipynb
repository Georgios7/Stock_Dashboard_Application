# %%
#import streamlit as st
from datetime import date
import pandas as pd
import streamlit as st
import yfinance as yf

# %%
date.today().strftime("%Y-%m-%d")
# Out:
# '2022-02-06'

# %%
stocks = ('GOOG', 'MSFT', 'DAR', 'AMD', 'ADBE','ABBV','AMZN','PG','PYPL','MU','NEE')
start_date = pd.to_datetime('2021-01-01')
today = pd.to_datetime('today')


data = yf.download(stocks, start_date, today)['Adj Close']
data.head()
# Out:
# [*********************100%***********************]  11 of 11 completed
#                  ABBV        ADBE        AMD         AMZN        DAR  \
# Date
# 2019-12-31  79.233505  329.809998  45.860001  1847.839966  28.080000
# 2020-01-02  80.137352  334.429993  49.099998  1898.010010  28.270000
# 2020-01-03  79.376686  331.809998  48.599998  1874.969971  28.910000
# 2020-01-06  80.003105  333.709991  48.389999  1902.880005  28.889999
# 2020-01-07  79.546715  333.390015  48.250000  1906.859985  28.690001
#
#                    GOOG        MSFT         MU        NEE          PG  \
# Date
# 2019-12-31  1337.020020  154.749756  53.647728  58.171944  118.260437
# 2020-01-02  1367.369995  157.615128  55.253773  57.321564  116.849663
# 2020-01-03  1360.660034  155.652496  54.395882  57.729935  116.063774
# 2020-01-06  1394.209961  156.054855  53.438248  58.018208  116.224731
# 2020-01-07  1393.339966  154.632004  58.126690  57.967754  115.505142
#
#                   PYPL
# Date
# ...

# %%
data.shape
# Out:
# (530, 11)

# %%
1/11
# Out:
# 0.09090909090909091

# %%
import numpy as np

# %%
weights = np.array([0.091,0.091,0.091,0.091,0.091,0.091,0.091,0.091,0.091, 0.091 , 0.091]) 
weights.sum()
# Out:
# 1.001

# %%
returns = (data / data.shift(1))-1

# %%
returns = (data / data.shift(1))-1
# assume equal weights
weights = np.array([0.091,0.091,0.091,0.091,0.091,0.091,0.091,0.091,0.091, 0.091 , 0.091]) 
np.dot(returns,weights)

annual_returns = returns.mean()* 250
np.dot(annual_returns,weights)
# Out:
# 0.3348308260520149

# %%
data.pct_change()
# Out:
#                 ABBV      ADBE       AMD      AMZN       DAR      GOOG  \
# Date
# 2019-12-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2020-01-02  0.011407  0.014008  0.070650  0.027151  0.006766  0.022700
# 2020-01-03 -0.009492 -0.007834 -0.010183 -0.012139  0.022639 -0.004907
# 2020-01-06  0.007892  0.005726 -0.004321  0.014886 -0.000692  0.024657
# 2020-01-07 -0.005705 -0.000959 -0.002893  0.002092 -0.006923 -0.000624
# ...              ...       ...       ...       ...       ...       ...
# 2022-01-31 -0.007468  0.031149  0.085614  0.038864  0.016579  0.018073
# 2022-02-01  0.000804  0.003144  0.022144  0.010831  0.002509  0.016065
# 2022-02-02  0.011825 -0.005392  0.051207 -0.003843 -0.000469  0.073674
# 2022-02-03  0.015221 -0.041757 -0.021831 -0.078128 -0.026604 -0.036383
# 2022-02-04 -0.000568  0.005305  0.029314  0.135359  0.002251  0.002562
#
#                 MSFT        MU       NEE        PG      PYPL
# Date
# ...

# %%
(85-91)/91
# Out:
# -0.06593406593406594

# %%
norm_data.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
returns = (data / data.shift(1))-1

# %%
corr_matrix = returns.corr()
corr_matrix
# Out:
#           ABBV      ADBE       AMD      AMZN       DAR      GOOG      MSFT  \
# ABBV  1.000000  0.427214  0.311189  0.270956  0.369931  0.525720  0.528153
# ADBE  0.427214  1.000000  0.617566  0.672221  0.391219  0.723547  0.831926
# AMD   0.311189  0.617566  1.000000  0.550630  0.341205  0.546020  0.618150
# AMZN  0.270956  0.672221  0.550630  1.000000  0.250201  0.625953  0.674459
# DAR   0.369931  0.391219  0.341205  0.250201  1.000000  0.437887  0.418461
# GOOG  0.525720  0.723547  0.546020  0.625953  0.437887  1.000000  0.812591
# MSFT  0.528153  0.831926  0.618150  0.674459  0.418461  0.812591  1.000000
# MU    0.376629  0.533255  0.556293  0.414511  0.528712  0.570365  0.596840
# NEE   0.409964  0.463119  0.391621  0.356659  0.406586  0.505485  0.563408
# PG    0.464550  0.460804  0.324147  0.321916  0.308500  0.500344  0.588005
# PYPL  0.358919  0.655057  0.500394  0.537119  0.356421  0.537681  0.641630
#
#             MU       NEE        PG      PYPL
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(15, 8))
sns.heatmap(returns.corr(), cmap="YlGnBu", annot=True)
#st.pyplot(fig)
# Out:
# <AxesSubplot:>

# %%
sns.set(rc = {'figure.figsize':(15,8)})
dataplot = sns.heatmap(returns.corr(), cmap="YlGnBu", annot=True)
mp.show()

# %%
data = yf.download(stocks, start, end)['Adj Close']

# Adj-Close Data
st.subheader(' Adj-Close Prices')
# Adjdata.index.strftime('%Y-%m-%d')
data.index.strftime("%Y-%m-%d")
# Out:
# [*********************100%***********************]  11 of 11 completed
# Index(['2019-12-31', '2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07',
#        '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13', '2020-01-14',
#        ...
#        '2022-01-24', '2022-01-25', '2022-01-26', '2022-01-27', '2022-01-28',
#        '2022-01-31', '2022-02-01', '2022-02-02', '2022-02-03', '2022-02-04'],
#       dtype='object', name='Date', length=530)

# %%
data.head()
# Out:
#                  ABBV        ADBE        AMD         AMZN        DAR  \
# Date
# 2019-12-31  79.233505  329.809998  45.860001  1847.839966  28.080000
# 2020-01-02  80.137352  334.429993  49.099998  1898.010010  28.270000
# 2020-01-03  79.376686  331.809998  48.599998  1874.969971  28.910000
# 2020-01-06  80.003113  333.709991  48.389999  1902.880005  28.889999
# 2020-01-07  79.546715  333.390015  48.250000  1906.859985  28.690001
#
#                    GOOG        MSFT         MU        NEE          PG  \
# Date
# 2019-12-31  1337.020020  154.749741  53.647728  58.171944  118.260452
# 2020-01-02  1367.369995  157.615097  55.253769  57.321560  116.849663
# 2020-01-03  1360.660034  155.652527  54.395885  57.729935  116.063774
# 2020-01-06  1394.209961  156.054840  53.438244  58.018204  116.224739
# 2020-01-07  1393.339966  154.632004  58.126686  57.967754  115.505142
#
#                   PYPL
# Date
# 2019-12-31  108.169998
# 2020-01-02  110.750000
# 2020-01-03  108.760002
# ...

# %%
data.reset_index()
# Out:
#           Date        ABBV        ADBE         AMD         AMZN        DAR  \
# 0   2019-12-31   79.233505  329.809998   45.860001  1847.839966  28.080000
# 1   2020-01-02   80.137352  334.429993   49.099998  1898.010010  28.270000
# 2   2020-01-03   79.376686  331.809998   48.599998  1874.969971  28.910000
# 3   2020-01-06   80.003113  333.709991   48.389999  1902.880005  28.889999
# 4   2020-01-07   79.546715  333.390015   48.250000  1906.859985  28.690001
# ..         ...         ...         ...         ...          ...        ...
# 525 2022-01-31  136.889999  534.299988  114.250000  2991.469971  63.770000
# 526 2022-02-01  137.000000  535.979980  116.779999  3023.870117  63.930000
# 527 2022-02-02  138.619995  533.090027  122.760002  3012.250000  63.900002
# 528 2022-02-03  140.729996  510.829987  120.080002  2776.909912  62.200001
# 529 2022-02-04  140.649994  513.539978  123.599998  3152.790039  62.340000
#
# ...

# %%
returns.plot()
# Out:
# <AxesSubplot:xlabel='Date'>
